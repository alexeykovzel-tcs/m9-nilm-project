# %%
import datastore
import visuals
import signs

# %%
data = datastore.load_sample_file()

# %%
visuals.plot_tagged_data(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 visuals.plot_tagged_data(data)
#
# File ~/Projects/ml-project/visuals.py:33, in plot_tagged_data(data, has_labels)
#      31 min_ts = min(x[2] for x in data['TaggingInfo'])
#      32 max_ts = max(x[3] for x in data['TaggingInfo'])
# ---> 33 plot_data(data, time_range=(min_ts, max_ts), has_labels=has_labels)
#
# File ~/Projects/ml-project/visuals.py:14, in plot_data(data, has_labels, time_range)
#      11 if time_range is not None:
#      12     data = trunc_data(data, time_range)
# ---> 14 plot_real_power(data, axs[0])
#      15 plot_reactive_power(data, axs[1])
#      16 plot_power_factor(data, axs[2])
#
# File ~/Projects/ml-project/visuals.py:37, in plot_real_power(data, ax, ts_range)
#      36 def plot_real_power(data, ax=None, ts_range=None):
# ...

# %%
signs.sign_and_plot_tags(data)
