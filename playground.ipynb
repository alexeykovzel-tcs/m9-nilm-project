# %%
import datastore
import visuals
import matplotlib.pyplot as plt
import numpy as np
import lph

# %%
data = datastore.load_sample_file()

# %%
visuals.plot_data(data), 'L1_Pf'

# %%
visuals.plot_tagged_data(data)

# %%
l1_hist = lph.lph_histogram(data['L1_Real'])
plt.bar(np.arange(256), l1_hist)
plt.show()
