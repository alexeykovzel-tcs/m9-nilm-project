# %%
from src.data_loader import load_train
from src.visuals import plot

# %%
data_0 = load_train('h1', 0)

# %%
plot(data_0, show_tags=False)

# %%
plot(data_0.truncate_tagged(), show_tags=False)

# %%
data_1 = load_train('h1', 1)

# %%
plot(data_1, show_tags=False)

# %%
plot(data_1.truncate_tagged())

# %%
data_2 = load_train('h1', 2)

# %%
plot(data_2, show_tags=False)

# %%
plot(data_2.truncate_tagged(), show_tags=False)
