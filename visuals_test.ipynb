# %%
from src.meter_data import load_sample
from src.visuals import plot

# %%
data_0 = load_sample(0)

# %%
plot(data_0, show_tags=False)

# %%
plot(data_0.tagged())

# %%
data_1 = load_sample(1)

# %%
plot(data_1, show_tags=False)

# %%
plot(data_1.tagged(), show_tags=False)

# %%
data_2 = load_sample(2)

# %%
plot(data_2, show_tags=False)

# %%
plot(data_2.tagged())
