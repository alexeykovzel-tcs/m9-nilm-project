# %%
import loader
import visuals

# %%
train_files = loader.load_train_files()
test_files = loader.load_test_files()

# %%
visuals.plot_all_data(train_files[0])

# %%
visuals.plot_tagged_data(train_files[0])

# %%
visuals.plot_all_data(train_files[1])

# %%
visuals.plot_tagged_data(train_files[1], has_labels=True)
