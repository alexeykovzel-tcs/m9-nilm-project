# %%
import loader
import visuals

# %%
data = loader.load_h1(loader.train_files[0])

# %%
visuals.belkin_plot_data(data)

# %%
min_ts = min(x[2] for x in data['TaggingInfo'])
max_ts = max(x[3] for x in data['TaggingInfo'])

tags = [x[1][0] for x in data['TaggingInfo']]
print('tags:', tags)

visuals.belkin_plot_data(data, ts_range=(min_ts, max_ts), tags=['Washer', 'Toaster'])
# Out:
# tags: ['Washer', 'Dryer', 'Toaster', 'Portable Vacuum', 'Central Vacuum']

# %%
visuals.test(data, ts_range=(min_ts, max_ts), tags=['Washer', 'Toaster'])
